# %% [markdown]
# # Day 1: Starting with tensorflow because I am pumped and determined about taking the tensorflow certification exam

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Define the data for our training
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
#Define the model
model=keras.Sequential(
        [keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer="sgd",loss="mean_squared_error")

# %%
#Fitting the model and training it
history=model.fit(xs,ys,epochs=500)
# Out:
# Train on 6 samples
# Epoch 1/500
# 6/6 [==============================] - 1s 169ms/sample - loss: 12.1483
# Epoch 2/500
# 6/6 [==============================] - 0s 498us/sample - loss: 9.7816
# Epoch 3/500
# 6/6 [==============================] - 0s 493us/sample - loss: 7.9151
# Epoch 4/500
# 6/6 [==============================] - 0s 591us/sample - loss: 6.4421
# Epoch 5/500
# 6/6 [==============================] - 0s 499us/sample - loss: 5.2787
# Epoch 6/500
# 6/6 [==============================] - 0s 499us/sample - loss: 4.3592
# Epoch 7/500
# 6/6 [==============================] - 0s 665us/sample - loss: 3.6315
# Epoch 8/500
# 6/6 [==============================] - 0s 631us/sample - loss: 3.0548
# Epoch 9/500
# 6/6 [==============================] - 0s 499us/sample - loss: 2.5970
# Epoch 10/500
# 6/6 [==============================] - 0s 665us/sample - loss: 2.2329
# Epoch 11/500
# 6/6 [==============================] - 0s 617us/sample - loss: 1.9425
# Epoch 12/500
# ...

# %%
#Visualize the loss per epoch
plt.plot(history.history['loss'])
plt.title("Loss per epoch")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.show()

# %%
model.predict([10.0])
# Out:
# array([[18.982267]], dtype=float32)

# %%
history.history.keys()
# Out:
# dict_keys(['loss'])
